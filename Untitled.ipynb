# %%
import pandas as pd

# %%
df = pd.read_csv("/home/eli/Downloads/STUPIDFUCKYOU.csv")

# %%
print(df)
# Out:
#     Unnamed: 0                      team.name                     home.park  \
# 0         2896           Arizona Diamondbacks                   Chase Field
# 1         2897                 Atlanta Braves                 SunTrust Park
# 2         2898              Baltimore Orioles   Oriole Park at Camden Yards
# 3         2899                 Boston Red Sox                Fenway Park II
# 4         2900              Chicago White Sox         Guaranteed Rate Field
# 5         2901                   Chicago Cubs                 Wrigley Field
# 6         2902                Cincinnati Reds      Great American Ball Park
# 7         2903              Cleveland Indians             Progressive Field
# 8         2904               Colorado Rockies                   Coors Field
# 9         2905                 Detroit Tigers                 Comerica Park
# 10        2906                 Houston Astros              Minute Maid Park
# ...

# %%
print(tmp)
# Out:
#                         team.name                     home.park  \
# 0            Arizona Diamondbacks                   Chase Field
# 1                  Atlanta Braves                 SunTrust Park
# 2               Baltimore Orioles   Oriole Park at Camden Yards
# 3                  Boston Red Sox                Fenway Park II
# 4               Chicago White Sox         Guaranteed Rate Field
# 5                    Chicago Cubs                 Wrigley Field
# 6                 Cincinnati Reds      Great American Ball Park
# 7               Cleveland Indians             Progressive Field
# 8                Colorado Rockies                   Coors Field
# 9                  Detroit Tigers                 Comerica Park
# 10                 Houston Astros              Minute Maid Park
# 11             Kansas City Royals              Kauffman Stadium
# 12  Los Angeles Angels of Anaheim      Angel Stadium of Anaheim
# 13            Los Angeles Dodgers                Dodger Stadium
# ...
